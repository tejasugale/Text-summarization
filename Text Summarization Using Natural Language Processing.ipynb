# %%
# source text
data = """Natural language processing (NLP) is a subfield of linguistics, computer science, and artificial intelligence concerned with the interactions between computers and human language, in particular how to program computers to process and analyze large amounts of natural language data.\n
             Challenges in natural language processing frequently involve speech recognition, natural language understanding, and natural-language generation.\n
             Natural language processing has its roots in the 1950s.\n
             Already in 1950, Alan Turing published an article titled Computing Machinery and Intelligence which proposed what is now called the Turing test as a criterion of intelligence, a task that involves the automated interpretation and generation of natural language, but at the time not articulated as a problem separate from artificial intelligence.\n
             The following is a list of some of the most commonly researched tasks in natural language processing.\n
             Some of these tasks have direct real-world applications, while others more commonly serve as subtasks that are used to aid in solving larger tasks.\n
             Though natural language processing tasks are closely intertwined, they can be subdivided into categories for convenience.\n"""

# %%
import nltk
# Out:
# C:\Users\user\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
nltk.download('punkt')
nltk.download('stopwords')
all_sentences=nltk.sent_tokenize(data)

all_words=[nltk.word_tokenize(sent) for sent in all_sentences]
from nltk.corpus import stopwords
for i in range(len(all_words)):
    all_words[i]=[w for w in all_words[i] if w not in stopwords.words('english')]
    print(all_words)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [['Natural', 'language', 'processing', '(', 'NLP', ')', 'subfield', 'linguistics', ',', 'computer', 'science', ',', 'artificial', 'intelligence', 'concerned', 'interactions', 'computers', 'human', 'language', ',', 'particular', 'program', 'computers', 'process', 'analyze', 'large', 'amounts', 'natural', 'language', 'data', '.'], ['Challenges', 'in', 'natural', 'language', 'processing', 'frequently', 'involve', 'speech', 'recognition', ',', 'natural', 'language', 'understanding', ',', 'and', 'natural-language', 'generation', '.'], ['Natural', 'language', 'processing', 'has', 'its', 'roots', 'in', 'the', '1950s', '.'], ['Already', 'in', '1950', ',', 'Alan', 'Turing', 'published', 'an', 'article', 'titled', 'Computing', 'Machinery', 'and', 'Intelligence', 'which', 'proposed', 'what', 'is', 'now', 'called', 'the', 'Turing', 'test', 'as', 'a', 'criterion', 'of', 'intelligence', ',', 'a', 'task', 'that', 'involves', 'the', 'automated', 'interpretation', 'and', 'generation', 'of', 'natural', 'language', ',', 'but', 'at', 'the', 'time', 'not', 'articulated', 'as', 'a', 'problem', 'separate', 'from', 'artificial', 'intelligence', '.'], ['The', 'following', 'is', 'a', 'list', 'of', 'some', 'of', 'the', 'most', 'commonly', 'researched', 'tasks', 'in', 'natural', 'language', 'processing', '.'], ['Some', 'of', 'these', 'tasks', 'have', 'direct', 'real-world', 'applications', ',', 'while', 'others', 'more', 'commonly', 'serve', 'as', 'subtasks', 'that', 'are', 'used', 'to', 'aid', 'in', 'solving', 'larger', 'tasks', '.'], ['Though', 'natural', 'language', 'processing', 'tasks', 'are', 'closely', 'intertwined', ',', 'they', 'can', 'be', 'subdivided', 'into', 'categories', 'for', 'convenience', '.']]
# [['Natural', 'language', 'processing', '(', 'NLP', ')', 'subfield', 'linguistics', ',', 'computer', 'science', ',', 'artificial', 'intelligence', 'concerned', 'interactions', 'computers', 'human', 'language', ',', 'particular', 'program', 'computers', 'process', 'analyze', 'large', 'amounts', 'natural', 'language', 'data', '.'], ['Challenges', 'natural', 'language', 'processing', 'frequently', 'involve', 'speech', 'recognition', ',', 'natural', 'language', 'understanding', ',', 'natural-language', 'generation', '.'], ['Natural', 'language', 'processing', 'has', 'its', 'roots', 'in', 'the', '1950s', '.'], ['Already', 'in', '1950', ',', 'Alan', 'Turing', 'published', 'an', 'article', 'titled', 'Computing', 'Machinery', 'and', 'Intelligence', 'which', 'proposed', 'what', 'is', 'now', 'called', 'the', 'Turing', 'test', 'as', 'a', 'criterion', 'of', 'intelligence', ',', 'a', 'task', 'that', 'involves', 'the', 'automated', 'interpretation', 'and', 'generation', 'of', 'natural', 'language', ',', 'but', 'at', 'the', 'time', 'not', 'articulated', 'as', 'a', 'problem', 'separate', 'from', 'artificial', 'intelligence', '.'], ['The', 'following', 'is', 'a', 'list', 'of', 'some', 'of', 'the', 'most', 'commonly', 'researched', 'tasks', 'in', 'natural', 'language', 'processing', '.'], ['Some', 'of', 'these', 'tasks', 'have', 'direct', 'real-world', 'applications', ',', 'while', 'others', 'more', 'commonly', 'serve', 'as', 'subtasks', 'that', 'are', 'used', 'to', 'aid', 'in', 'solving', 'larger', 'tasks', '.'], ['Though', 'natural', 'language', 'processing', 'tasks', 'are', 'closely', 'intertwined', ',', 'they', 'can', 'be', 'subdivided', 'into', 'categories', 'for', 'convenience', '.']]
# [['Natural', 'language', 'processing', '(', 'NLP', ')', 'subfield', 'linguistics', ',', 'computer', 'science', ',', 'artificial', 'intelligence', 'concerned', 'interactions', 'computers', 'human', 'language', ',', 'particular', 'program', 'computers', 'process', 'analyze', 'large', 'amounts', 'natural', 'language', 'data', '.'], ['Challenges', 'natural', 'language', 'processing', 'frequently', 'involve', 'speech', 'recognition', ',', 'natural', 'language', 'understanding', ',', 'natural-language', 'generation', '.'], ['Natural', 'language', 'processing', 'roots', '1950s', '.'], ['Already', 'in', '1950', ',', 'Alan', 'Turing', 'published', 'an', 'article', 'titled', 'Computing', 'Machinery', 'and', 'Intelligence', 'which', 'proposed', 'what', 'is', 'now', 'called', 'the', 'Turing', 'test', 'as', 'a', 'criterion', 'of', 'intelligence', ',', 'a', 'task', 'that', 'involves', 'the', 'automated', 'interpretation', 'and', 'generation', 'of', 'natural', 'language', ',', 'but', 'at', 'the', 'time', 'not', 'articulated', 'as', 'a', 'problem', 'separate', 'from', 'artificial', 'intelligence', '.'], ['The', 'following', 'is', 'a', 'list', 'of', 'some', 'of', 'the', 'most', 'commonly', 'researched', 'tasks', 'in', 'natural', 'language', 'processing', '.'], ['Some', 'of', 'these', 'tasks', 'have', 'direct', 'real-world', 'applications', ',', 'while', 'others', 'more', 'commonly', 'serve', 'as', 'subtasks', 'that', 'are', 'used', 'to', 'aid', 'in', 'solving', 'larger', 'tasks', '.'], ['Though', 'natural', 'language', 'processing', 'tasks', 'are', 'closely', 'intertwined', ',', 'they', 'can', 'be', 'subdivided', 'into', 'categories', 'for', 'convenience', '.']]
# [['Natural', 'language', 'processing', '(', 'NLP', ')', 'subfield', 'linguistics', ',', 'computer', 'science', ',', 'artificial', 'intelligence', 'concerned', 'interactions', 'computers', 'human', 'language', ',', 'particular', 'program', 'computers', 'process', 'analyze', 'large', 'amounts', 'natural', 'language', 'data', '.'], ['Challenges', 'natural', 'language', 'processing', 'frequently', 'involve', 'speech', 'recognition', ',', 'natural', 'language', 'understanding', ',', 'natural-language', 'generation', '.'], ['Natural', 'language', 'processing', 'roots', '1950s', '.'], ['Already', '1950', ',', 'Alan', 'Turing', 'published', 'article', 'titled', 'Computing', 'Machinery', 'Intelligence', 'proposed', 'called', 'Turing', 'test', 'criterion', 'intelligence', ',', 'task', 'involves', 'automated', 'interpretation', 'generation', 'natural', 'language', ',', 'time', 'articulated', 'problem', 'separate', 'artificial', 'intelligence', '.'], ['The', 'following', 'is', 'a', 'list', 'of', 'some', 'of', 'the', 'most', 'commonly', 'researched', 'tasks', 'in', 'natural', 'language', 'processing', '.'], ['Some', 'of', 'these', 'tasks', 'have', 'direct', 'real-world', 'applications', ',', 'while', 'others', 'more', 'commonly', 'serve', 'as', 'subtasks', 'that', 'are', 'used', 'to', 'aid', 'in', 'solving', 'larger', 'tasks', '.'], ['Though', 'natural', 'language', 'processing', 'tasks', 'are', 'closely', 'intertwined', ',', 'they', 'can', 'be', 'subdivided', 'into', 'categories', 'for', 'convenience', '.']]
# [['Natural', 'language', 'processing', '(', 'NLP', ')', 'subfield', 'linguistics', ',', 'computer', 'science', ',', 'artificial', 'intelligence', 'concerned', 'interactions', 'computers', 'human', 'language', ',', 'particular', 'program', 'computers', 'process', 'analyze', 'large', 'amounts', 'natural', 'language', 'data', '.'], ['Challenges', 'natural', 'language', 'processing', 'frequently', 'involve', 'speech', 'recognition', ',', 'natural', 'language', 'understanding', ',', 'natural-language', 'generation', '.'], ['Natural', 'language', 'processing', 'roots', '1950s', '.'], ['Already', '1950', ',', 'Alan', 'Turing', 'published', 'article', 'titled', 'Computing', 'Machinery', 'Intelligence', 'proposed', 'called', 'Turing', 'test', 'criterion', 'intelligence', ',', 'task', 'involves', 'automated', 'interpretation', 'generation', 'natural', 'language', ',', 'time', 'articulated', 'problem', 'separate', 'artificial', 'intelligence', '.'], ['The', 'following', 'list', 'commonly', 'researched', 'tasks', 'natural', 'language', 'processing', '.'], ['Some', 'of', 'these', 'tasks', 'have', 'direct', 'real-world', 'applications', ',', 'while', 'others', 'more', 'commonly', 'serve', 'as', 'subtasks', 'that', 'are', 'used', 'to', 'aid', 'in', 'solving', 'larger', 'tasks', '.'], ['Though', 'natural', 'language', 'processing', 'tasks', 'are', 'closely', 'intertwined', ',', 'they', 'can', 'be', 'subdivided', 'into', 'categories', 'for', 'convenience', '.']]
# [['Natural', 'language', 'processing', '(', 'NLP', ')', 'subfield', 'linguistics', ',', 'computer', 'science', ',', 'artificial', 'intelligence', 'concerned', 'interactions', 'computers', 'human', 'language', ',', 'particular', 'program', 'computers', 'process', 'analyze', 'large', 'amounts', 'natural', 'language', 'data', '.'], ['Challenges', 'natural', 'language', 'processing', 'frequently', 'involve', 'speech', 'recognition', ',', 'natural', 'language', 'understanding', ',', 'natural-language', 'generation', '.'], ['Natural', 'language', 'processing', 'roots', '1950s', '.'], ['Already', '1950', ',', 'Alan', 'Turing', 'published', 'article', 'titled', 'Computing', 'Machinery', 'Intelligence', 'proposed', 'called', 'Turing', 'test', 'criterion', 'intelligence', ',', 'task', 'involves', 'automated', 'interpretation', 'generation', 'natural', 'language', ',', 'time', 'articulated', 'problem', 'separate', 'artificial', 'intelligence', '.'], ['The', 'following', 'list', 'commonly', 'researched', 'tasks', 'natural', 'language', 'processing', '.'], ['Some', 'tasks', 'direct', 'real-world', 'applications', ',', 'others', 'commonly', 'serve', 'subtasks', 'used', 'aid', 'solving', 'larger', 'tasks', '.'], ['Though', 'natural', 'language', 'processing', 'tasks', 'are', 'closely', 'intertwined', ',', 'they', 'can', 'be', 'subdivided', 'into', 'categories', 'for', 'convenience', '.']]
# [['Natural', 'language', 'processing', '(', 'NLP', ')', 'subfield', 'linguistics', ',', 'computer', 'science', ',', 'artificial', 'intelligence', 'concerned', 'interactions', 'computers', 'human', 'language', ',', 'particular', 'program', 'computers', 'process', 'analyze', 'large', 'amounts', 'natural', 'language', 'data', '.'], ['Challenges', 'natural', 'language', 'processing', 'frequently', 'involve', 'speech', 'recognition', ',', 'natural', 'language', 'understanding', ',', 'natural-language', 'generation', '.'], ['Natural', 'language', 'processing', 'roots', '1950s', '.'], ['Already', '1950', ',', 'Alan', 'Turing', 'published', 'article', 'titled', 'Computing', 'Machinery', 'Intelligence', 'proposed', 'called', 'Turing', 'test', 'criterion', 'intelligence', ',', 'task', 'involves', 'automated', 'interpretation', 'generation', 'natural', 'language', ',', 'time', 'articulated', 'problem', 'separate', 'artificial', 'intelligence', '.'], ['The', 'following', 'list', 'commonly', 'researched', 'tasks', 'natural', 'language', 'processing', '.'], ['Some', 'tasks', 'direct', 'real-world', 'applications', ',', 'others', 'commonly', 'serve', 'subtasks', 'used', 'aid', 'solving', 'larger', 'tasks', '.'], ['Though', 'natural', 'language', 'processing', 'tasks', 'closely', 'intertwined', ',', 'subdivided', 'categories', 'convenience', '.']]

# %%
from gensim.models import Word2Vec
word2vec=Word2Vec(all_words,min_count=1)
word2vec.wv.most_similar('natural')
# Out:
# [('test', 0.20554330945014954),
#  ('NLP', 0.1794852614402771),
#  ('subfield', 0.1642543226480484),
#  ('criterion', 0.16400839388370514),
#  ('researched', 0.15037602186203003),
#  ('task', 0.13987784087657928),
#  ('larger', 0.1360655128955841),
#  ('tasks', 0.13299749791622162),
#  ('closely', 0.12206412851810455),
#  ('applications', 0.09703784435987473)]

# %%
word2vec.wv.most_similar('language')
# Out:
# [('recognition', 0.19066877663135529),
#  ('data', 0.18839259445667267),
#  ('serve', 0.18468110263347626),
#  ('NLP', 0.16145464777946472),
#  ('roots', 0.16034404933452606),
#  ('automated', 0.1600670963525772),
#  ('Machinery', 0.1595340073108673),
#  ('science', 0.13824574649333954),
#  ('separate', 0.1350008249282837),
#  ('speech', 0.12905026972293854)]

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\user\anaconda3\lib\site-packages (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.0.0)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: six>=1.12.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.23.4)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.26.3)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.60.0)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.9.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (21.3)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (61.2.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.12.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\user\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\user\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.27.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\user\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.25.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\user\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\user\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\user\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.7.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\user\anaconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\user\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.26.9)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.15.0->tensorflow) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, LSTM , Embedding
# Out:
# WARNING:tensorflow:From C:\Users\user\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts([data])
encoded=tokenizer.texts_to_sequences([data])[0]
vocab_size=len(tokenizer.word_index)+1
print('Vocabulary Size: %d'%vocab_size )
# Out:
# Vocabulary Size: 108

# %%
import numpy as np
sequences=list()
for i in range(1,len(encoded)):
    sequence=encoded[i-1:i+1]
    sequences.append(sequence)
print('Total Sequences: %d'%len(sequences))
sequences=np.array(sequences)
X,y=sequences[:,0],sequences[:,1]
# Out:
# Total Sequences: 173

# %%
# one hot encode outputs
y = to_categorical(y, num_classes=vocab_size)
# define model
model = Sequential()
model.add(Embedding(vocab_size, 10, input_length=1))
model.add(LSTM(50))
model.add(Dense(vocab_size, activation='softmax'))
print(model.summary())
# compile network
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit network
model.fit(X, y, epochs=200, verbose=2)
# Out:
# WARNING:tensorflow:From C:\Users\user\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1, 10)             1080
#
#  lstm (LSTM)                 (None, 50)                12200
#
#  dense (Dense)               (None, 108)               5508
#
# =================================================================
# Total params: 18788 (73.39 KB)
# Trainable params: 18788 (73.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# WARNING:tensorflow:From C:\Users\user\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\user\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\user\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 6/6 - 5s - loss: 4.6822 - accuracy: 0.0289 - 5s/epoch - 827ms/step
# Epoch 2/200
# 6/6 - 0s - loss: 4.6789 - accuracy: 0.0809 - 27ms/epoch - 4ms/step
# Epoch 3/200
# 6/6 - 0s - loss: 4.6761 - accuracy: 0.0925 - 28ms/epoch - 5ms/step
# Epoch 4/200
# 6/6 - 0s - loss: 4.6734 - accuracy: 0.0925 - 27ms/epoch - 4ms/step
# Epoch 5/200
# 6/6 - 0s - loss: 4.6704 - accuracy: 0.0983 - 27ms/epoch - 5ms/step
# Epoch 6/200
# 6/6 - 0s - loss: 4.6672 - accuracy: 0.0983 - 34ms/epoch - 6ms/step
# Epoch 7/200
# 6/6 - 0s - loss: 4.6637 - accuracy: 0.0983 - 30ms/epoch - 5ms/step
# Epoch 8/200
# 6/6 - 0s - loss: 4.6597 - accuracy: 0.0983 - 27ms/epoch - 4ms/step
# Epoch 9/200
# 6/6 - 0s - loss: 4.6553 - accuracy: 0.0983 - 30ms/epoch - 5ms/step
# Epoch 10/200
# 6/6 - 0s - loss: 4.6503 - accuracy: 0.0983 - 32ms/epoch - 5ms/step
# Epoch 11/200
# 6/6 - 0s - loss: 4.6445 - accuracy: 0.1040 - 60ms/epoch - 10ms/step
# Epoch 12/200
# 6/6 - 0s - loss: 4.6378 - accuracy: 0.1040 - 22ms/epoch - 4ms/step
# Epoch 13/200
# 6/6 - 0s - loss: 4.6305 - accuracy: 0.1040 - 20ms/epoch - 3ms/step
# Epoch 14/200
# 6/6 - 0s - loss: 4.6213 - accuracy: 0.1040 - 22ms/epoch - 4ms/step
# Epoch 15/200
# 6/6 - 0s - loss: 4.6113 - accuracy: 0.1040 - 23ms/epoch - 4ms/step
# Epoch 16/200
# 6/6 - 0s - loss: 4.6002 - accuracy: 0.1040 - 29ms/epoch - 5ms/step
# Epoch 17/200
# 6/6 - 0s - loss: 4.5859 - accuracy: 0.1040 - 38ms/epoch - 6ms/step
# Epoch 18/200
# 6/6 - 0s - loss: 4.5713 - accuracy: 0.1040 - 30ms/epoch - 5ms/step
# Epoch 19/200
# 6/6 - 0s - loss: 4.5532 - accuracy: 0.1040 - 23ms/epoch - 4ms/step
# Epoch 20/200
# 6/6 - 0s - loss: 4.5332 - accuracy: 0.1040 - 25ms/epoch - 4ms/step
# Epoch 21/200
# 6/6 - 0s - loss: 4.5103 - accuracy: 0.1040 - 26ms/epoch - 4ms/step
# Epoch 22/200
# 6/6 - 0s - loss: 4.4843 - accuracy: 0.1040 - 28ms/epoch - 5ms/step
# Epoch 23/200
# 6/6 - 0s - loss: 4.4557 - accuracy: 0.1040 - 22ms/epoch - 4ms/step
# Epoch 24/200
# 6/6 - 0s - loss: 4.4216 - accuracy: 0.1040 - 24ms/epoch - 4ms/step
# Epoch 25/200
# 6/6 - 0s - loss: 4.3851 - accuracy: 0.1040 - 24ms/epoch - 4ms/step
# Epoch 26/200
# 6/6 - 0s - loss: 4.3468 - accuracy: 0.1040 - 23ms/epoch - 4ms/step
# Epoch 27/200
# 6/6 - 0s - loss: 4.3046 - accuracy: 0.1040 - 23ms/epoch - 4ms/step
# Epoch 28/200
# 6/6 - 0s - loss: 4.2571 - accuracy: 0.1040 - 24ms/epoch - 4ms/step
# Epoch 29/200
# 6/6 - 0s - loss: 4.2115 - accuracy: 0.1040 - 26ms/epoch - 4ms/step
# Epoch 30/200
# 6/6 - 0s - loss: 4.1578 - accuracy: 0.1040 - 28ms/epoch - 5ms/step
# Epoch 31/200
# 6/6 - 0s - loss: 4.1102 - accuracy: 0.1040 - 21ms/epoch - 3ms/step
# Epoch 32/200
# 6/6 - 0s - loss: 4.0574 - accuracy: 0.1040 - 26ms/epoch - 4ms/step
# Epoch 33/200
# 6/6 - 0s - loss: 4.0069 - accuracy: 0.1040 - 35ms/epoch - 6ms/step
# Epoch 34/200
# 6/6 - 0s - loss: 3.9601 - accuracy: 0.1040 - 23ms/epoch - 4ms/step
# Epoch 35/200
# 6/6 - 0s - loss: 3.9158 - accuracy: 0.1040 - 23ms/epoch - 4ms/step
# Epoch 36/200
# 6/6 - 0s - loss: 3.8738 - accuracy: 0.1040 - 33ms/epoch - 5ms/step
# Epoch 37/200
# 6/6 - 0s - loss: 3.8346 - accuracy: 0.1098 - 32ms/epoch - 5ms/step
# Epoch 38/200
# 6/6 - 0s - loss: 3.7987 - accuracy: 0.1156 - 22ms/epoch - 4ms/step
# Epoch 39/200
# 6/6 - 0s - loss: 3.7633 - accuracy: 0.1156 - 25ms/epoch - 4ms/step
# Epoch 40/200
# 6/6 - 0s - loss: 3.7309 - accuracy: 0.1329 - 33ms/epoch - 6ms/step
# Epoch 41/200
# 6/6 - 0s - loss: 3.6999 - accuracy: 0.1445 - 22ms/epoch - 4ms/step
# Epoch 42/200
# 6/6 - 0s - loss: 3.6691 - accuracy: 0.1503 - 24ms/epoch - 4ms/step
# Epoch 43/200
# 6/6 - 0s - loss: 3.6402 - accuracy: 0.1561 - 27ms/epoch - 5ms/step
# Epoch 44/200
# 6/6 - 0s - loss: 3.6108 - accuracy: 0.1618 - 34ms/epoch - 6ms/step
# Epoch 45/200
# 6/6 - 0s - loss: 3.5821 - accuracy: 0.1561 - 24ms/epoch - 4ms/step
# Epoch 46/200
# 6/6 - 0s - loss: 3.5537 - accuracy: 0.1561 - 26ms/epoch - 4ms/step
# Epoch 47/200
# 6/6 - 0s - loss: 3.5253 - accuracy: 0.1561 - 25ms/epoch - 4ms/step
# Epoch 48/200
# 6/6 - 0s - loss: 3.4971 - accuracy: 0.1618 - 25ms/epoch - 4ms/step
# Epoch 49/200
# 6/6 - 0s - loss: 3.4684 - accuracy: 0.1734 - 23ms/epoch - 4ms/step
# Epoch 50/200
# 6/6 - 0s - loss: 3.4397 - accuracy: 0.1850 - 26ms/epoch - 4ms/step
# Epoch 51/200
# 6/6 - 0s - loss: 3.4118 - accuracy: 0.1850 - 32ms/epoch - 5ms/step
# Epoch 52/200
# 6/6 - 0s - loss: 3.3827 - accuracy: 0.1850 - 23ms/epoch - 4ms/step
# Epoch 53/200
# 6/6 - 0s - loss: 3.3541 - accuracy: 0.2081 - 26ms/epoch - 4ms/step
# Epoch 54/200
# 6/6 - 0s - loss: 3.3251 - accuracy: 0.2370 - 29ms/epoch - 5ms/step
# Epoch 55/200
# 6/6 - 0s - loss: 3.2967 - accuracy: 0.2370 - 29ms/epoch - 5ms/step
# Epoch 56/200
# 6/6 - 0s - loss: 3.2668 - accuracy: 0.2370 - 27ms/epoch - 4ms/step
# Epoch 57/200
# 6/6 - 0s - loss: 3.2376 - accuracy: 0.2370 - 31ms/epoch - 5ms/step
# Epoch 58/200
# 6/6 - 0s - loss: 3.2070 - accuracy: 0.2486 - 24ms/epoch - 4ms/step
# Epoch 59/200
# 6/6 - 0s - loss: 3.1780 - accuracy: 0.2659 - 28ms/epoch - 5ms/step
# Epoch 60/200
# 6/6 - 0s - loss: 3.1475 - accuracy: 0.2775 - 32ms/epoch - 5ms/step
# Epoch 61/200
# 6/6 - 0s - loss: 3.1172 - accuracy: 0.2890 - 32ms/epoch - 5ms/step
# Epoch 62/200
# 6/6 - 0s - loss: 3.0875 - accuracy: 0.3006 - 30ms/epoch - 5ms/step
# Epoch 63/200
# 6/6 - 0s - loss: 3.0566 - accuracy: 0.3064 - 26ms/epoch - 4ms/step
# Epoch 64/200
# 6/6 - 0s - loss: 3.0278 - accuracy: 0.3179 - 31ms/epoch - 5ms/step
# Epoch 65/200
# 6/6 - 0s - loss: 2.9975 - accuracy: 0.3237 - 34ms/epoch - 6ms/step
# Epoch 66/200
# 6/6 - 0s - loss: 2.9671 - accuracy: 0.3295 - 29ms/epoch - 5ms/step
# Epoch 67/200
# 6/6 - 0s - loss: 2.9381 - accuracy: 0.3410 - 29ms/epoch - 5ms/step
# Epoch 68/200
# 6/6 - 0s - loss: 2.9079 - accuracy: 0.3410 - 29ms/epoch - 5ms/step
# Epoch 69/200
# 6/6 - 0s - loss: 2.8786 - accuracy: 0.3410 - 30ms/epoch - 5ms/step
# Epoch 70/200
# 6/6 - 0s - loss: 2.8484 - accuracy: 0.3468 - 36ms/epoch - 6ms/step
# Epoch 71/200
# 6/6 - 0s - loss: 2.8184 - accuracy: 0.3410 - 31ms/epoch - 5ms/step
# Epoch 72/200
# 6/6 - 0s - loss: 2.7897 - accuracy: 0.3526 - 25ms/epoch - 4ms/step
# Epoch 73/200
# 6/6 - 0s - loss: 2.7588 - accuracy: 0.3584 - 27ms/epoch - 4ms/step
# Epoch 74/200
# 6/6 - 0s - loss: 2.7294 - accuracy: 0.3584 - 39ms/epoch - 7ms/step
# Epoch 75/200
# 6/6 - 0s - loss: 2.7005 - accuracy: 0.3584 - 24ms/epoch - 4ms/step
# Epoch 76/200
# 6/6 - 0s - loss: 2.6721 - accuracy: 0.3584 - 26ms/epoch - 4ms/step
# Epoch 77/200
# 6/6 - 0s - loss: 2.6427 - accuracy: 0.3584 - 28ms/epoch - 5ms/step
# Epoch 78/200
# 6/6 - 0s - loss: 2.6154 - accuracy: 0.3699 - 42ms/epoch - 7ms/step
# Epoch 79/200
# 6/6 - 0s - loss: 2.5862 - accuracy: 0.3931 - 33ms/epoch - 5ms/step
# Epoch 80/200
# 6/6 - 0s - loss: 2.5580 - accuracy: 0.3988 - 31ms/epoch - 5ms/step
# Epoch 81/200
# 6/6 - 0s - loss: 2.5292 - accuracy: 0.4104 - 29ms/epoch - 5ms/step
# Epoch 82/200
# 6/6 - 0s - loss: 2.5019 - accuracy: 0.4277 - 34ms/epoch - 6ms/step
# Epoch 83/200
# 6/6 - 0s - loss: 2.4745 - accuracy: 0.4277 - 29ms/epoch - 5ms/step
# Epoch 84/200
# 6/6 - 0s - loss: 2.4466 - accuracy: 0.4335 - 29ms/epoch - 5ms/step
# Epoch 85/200
# 6/6 - 0s - loss: 2.4204 - accuracy: 0.4335 - 30ms/epoch - 5ms/step
# Epoch 86/200
# 6/6 - 0s - loss: 2.3931 - accuracy: 0.4566 - 27ms/epoch - 4ms/step
# Epoch 87/200
# 6/6 - 0s - loss: 2.3668 - accuracy: 0.4509 - 27ms/epoch - 4ms/step
# Epoch 88/200
# 6/6 - 0s - loss: 2.3411 - accuracy: 0.4624 - 26ms/epoch - 4ms/step
# Epoch 89/200
# 6/6 - 0s - loss: 2.3157 - accuracy: 0.4740 - 36ms/epoch - 6ms/step
# Epoch 90/200
# 6/6 - 0s - loss: 2.2897 - accuracy: 0.4855 - 26ms/epoch - 4ms/step
# Epoch 91/200
# 6/6 - 0s - loss: 2.2652 - accuracy: 0.4913 - 28ms/epoch - 5ms/step
# Epoch 92/200
# 6/6 - 0s - loss: 2.2398 - accuracy: 0.4971 - 24ms/epoch - 4ms/step
# Epoch 93/200
# 6/6 - 0s - loss: 2.2149 - accuracy: 0.5029 - 25ms/epoch - 4ms/step
# Epoch 94/200
# 6/6 - 0s - loss: 2.1905 - accuracy: 0.5029 - 25ms/epoch - 4ms/step
# Epoch 95/200
# 6/6 - 0s - loss: 2.1667 - accuracy: 0.5087 - 26ms/epoch - 4ms/step
# Epoch 96/200
# 6/6 - 0s - loss: 2.1416 - accuracy: 0.5202 - 28ms/epoch - 5ms/step
# Epoch 97/200
# 6/6 - 0s - loss: 2.1182 - accuracy: 0.5202 - 30ms/epoch - 5ms/step
# Epoch 98/200
# 6/6 - 0s - loss: 2.0951 - accuracy: 0.5491 - 26ms/epoch - 4ms/step
# Epoch 99/200
# 6/6 - 0s - loss: 2.0721 - accuracy: 0.5607 - 31ms/epoch - 5ms/step
# Epoch 100/200
# 6/6 - 0s - loss: 2.0494 - accuracy: 0.5896 - 30ms/epoch - 5ms/step
# Epoch 101/200
# 6/6 - 0s - loss: 2.0256 - accuracy: 0.5896 - 50ms/epoch - 8ms/step
# Epoch 102/200
# 6/6 - 0s - loss: 2.0027 - accuracy: 0.5896 - 36ms/epoch - 6ms/step
# Epoch 103/200
# 6/6 - 0s - loss: 1.9804 - accuracy: 0.6012 - 29ms/epoch - 5ms/step
# Epoch 104/200
# 6/6 - 0s - loss: 1.9578 - accuracy: 0.5954 - 31ms/epoch - 5ms/step
# Epoch 105/200
# 6/6 - 0s - loss: 1.9352 - accuracy: 0.6127 - 25ms/epoch - 4ms/step
# Epoch 106/200
# 6/6 - 0s - loss: 1.9131 - accuracy: 0.6127 - 42ms/epoch - 7ms/step
# Epoch 107/200
# 6/6 - 0s - loss: 1.8915 - accuracy: 0.6069 - 37ms/epoch - 6ms/step
# Epoch 108/200
# 6/6 - 0s - loss: 1.8696 - accuracy: 0.6301 - 29ms/epoch - 5ms/step
# Epoch 109/200
# 6/6 - 0s - loss: 1.8491 - accuracy: 0.6301 - 34ms/epoch - 6ms/step
# Epoch 110/200
# 6/6 - 0s - loss: 1.8273 - accuracy: 0.6301 - 31ms/epoch - 5ms/step
# Epoch 111/200
# 6/6 - 0s - loss: 1.8069 - accuracy: 0.6358 - 33ms/epoch - 5ms/step
# Epoch 112/200
# 6/6 - 0s - loss: 1.7862 - accuracy: 0.6301 - 30ms/epoch - 5ms/step
# Epoch 113/200
# 6/6 - 0s - loss: 1.7666 - accuracy: 0.6416 - 31ms/epoch - 5ms/step
# Epoch 114/200
# 6/6 - 0s - loss: 1.7456 - accuracy: 0.6358 - 28ms/epoch - 5ms/step
# Epoch 115/200
# 6/6 - 0s - loss: 1.7259 - accuracy: 0.6474 - 31ms/epoch - 5ms/step
# Epoch 116/200
# 6/6 - 0s - loss: 1.7067 - accuracy: 0.6532 - 27ms/epoch - 4ms/step
# Epoch 117/200
# 6/6 - 0s - loss: 1.6871 - accuracy: 0.6532 - 29ms/epoch - 5ms/step
# Epoch 118/200
# 6/6 - 0s - loss: 1.6673 - accuracy: 0.6590 - 28ms/epoch - 5ms/step
# Epoch 119/200
# 6/6 - 0s - loss: 1.6483 - accuracy: 0.6590 - 27ms/epoch - 4ms/step
# Epoch 120/200
# 6/6 - 0s - loss: 1.6298 - accuracy: 0.6590 - 30ms/epoch - 5ms/step
# Epoch 121/200
# 6/6 - 0s - loss: 1.6112 - accuracy: 0.6705 - 33ms/epoch - 5ms/step
# Epoch 122/200
# 6/6 - 0s - loss: 1.5927 - accuracy: 0.6705 - 32ms/epoch - 5ms/step
# Epoch 123/200
# 6/6 - 0s - loss: 1.5752 - accuracy: 0.6705 - 30ms/epoch - 5ms/step
# Epoch 124/200
# 6/6 - 0s - loss: 1.5569 - accuracy: 0.6705 - 29ms/epoch - 5ms/step
# Epoch 125/200
# 6/6 - 0s - loss: 1.5392 - accuracy: 0.6763 - 31ms/epoch - 5ms/step
# Epoch 126/200
# 6/6 - 0s - loss: 1.5213 - accuracy: 0.6763 - 29ms/epoch - 5ms/step
# Epoch 127/200
# 6/6 - 0s - loss: 1.5055 - accuracy: 0.6763 - 28ms/epoch - 5ms/step
# Epoch 128/200
# 6/6 - 0s - loss: 1.4870 - accuracy: 0.6763 - 28ms/epoch - 5ms/step
# Epoch 129/200
# 6/6 - 0s - loss: 1.4698 - accuracy: 0.6763 - 29ms/epoch - 5ms/step
# Epoch 130/200
# 6/6 - 0s - loss: 1.4541 - accuracy: 0.6763 - 29ms/epoch - 5ms/step
# Epoch 131/200
# 6/6 - 0s - loss: 1.4375 - accuracy: 0.6763 - 27ms/epoch - 4ms/step
# Epoch 132/200
# 6/6 - 0s - loss: 1.4212 - accuracy: 0.6763 - 24ms/epoch - 4ms/step
# Epoch 133/200
# 6/6 - 0s - loss: 1.4057 - accuracy: 0.6763 - 24ms/epoch - 4ms/step
# Epoch 134/200
# 6/6 - 0s - loss: 1.3910 - accuracy: 0.6763 - 26ms/epoch - 4ms/step
# Epoch 135/200
# 6/6 - 0s - loss: 1.3749 - accuracy: 0.6763 - 76ms/epoch - 13ms/step
# Epoch 136/200
# 6/6 - 0s - loss: 1.3604 - accuracy: 0.6821 - 37ms/epoch - 6ms/step
# Epoch 137/200
# 6/6 - 0s - loss: 1.3455 - accuracy: 0.6763 - 30ms/epoch - 5ms/step
# Epoch 138/200
# 6/6 - 0s - loss: 1.3315 - accuracy: 0.6763 - 32ms/epoch - 5ms/step
# Epoch 139/200
# 6/6 - 0s - loss: 1.3174 - accuracy: 0.6879 - 23ms/epoch - 4ms/step
# Epoch 140/200
# 6/6 - 0s - loss: 1.3032 - accuracy: 0.6879 - 26ms/epoch - 4ms/step
# Epoch 141/200
# 6/6 - 0s - loss: 1.2900 - accuracy: 0.6879 - 32ms/epoch - 5ms/step
# Epoch 142/200
# 6/6 - 0s - loss: 1.2770 - accuracy: 0.6879 - 29ms/epoch - 5ms/step
# Epoch 143/200
# 6/6 - 0s - loss: 1.2647 - accuracy: 0.6879 - 27ms/epoch - 5ms/step
# Epoch 144/200
# 6/6 - 0s - loss: 1.2506 - accuracy: 0.6936 - 27ms/epoch - 5ms/step
# Epoch 145/200
# 6/6 - 0s - loss: 1.2378 - accuracy: 0.6879 - 28ms/epoch - 5ms/step
# Epoch 146/200
# 6/6 - 0s - loss: 1.2253 - accuracy: 0.6994 - 25ms/epoch - 4ms/step
# Epoch 147/200
# 6/6 - 0s - loss: 1.2139 - accuracy: 0.6994 - 25ms/epoch - 4ms/step
# Epoch 148/200
# 6/6 - 0s - loss: 1.2017 - accuracy: 0.6994 - 26ms/epoch - 4ms/step
# Epoch 149/200
# 6/6 - 0s - loss: 1.1899 - accuracy: 0.6994 - 26ms/epoch - 4ms/step
# Epoch 150/200
# 6/6 - 0s - loss: 1.1786 - accuracy: 0.6936 - 25ms/epoch - 4ms/step
# Epoch 151/200
# 6/6 - 0s - loss: 1.1674 - accuracy: 0.6994 - 21ms/epoch - 4ms/step
# Epoch 152/200
# 6/6 - 0s - loss: 1.1566 - accuracy: 0.6994 - 26ms/epoch - 4ms/step
# Epoch 153/200
# 6/6 - 0s - loss: 1.1453 - accuracy: 0.6994 - 26ms/epoch - 4ms/step
# Epoch 154/200
# 6/6 - 0s - loss: 1.1353 - accuracy: 0.6936 - 27ms/epoch - 5ms/step
# Epoch 155/200
# 6/6 - 0s - loss: 1.1241 - accuracy: 0.6994 - 23ms/epoch - 4ms/step
# Epoch 156/200
# 6/6 - 0s - loss: 1.1149 - accuracy: 0.6994 - 61ms/epoch - 10ms/step
# Epoch 157/200
# 6/6 - 0s - loss: 1.1043 - accuracy: 0.7052 - 27ms/epoch - 4ms/step
# Epoch 158/200
# 6/6 - 0s - loss: 1.0952 - accuracy: 0.6994 - 54ms/epoch - 9ms/step
# Epoch 159/200
# 6/6 - 0s - loss: 1.0847 - accuracy: 0.6994 - 29ms/epoch - 5ms/step
# Epoch 160/200
# 6/6 - 0s - loss: 1.0751 - accuracy: 0.6994 - 23ms/epoch - 4ms/step
# Epoch 161/200
# 6/6 - 0s - loss: 1.0665 - accuracy: 0.7052 - 24ms/epoch - 4ms/step
# Epoch 162/200
# 6/6 - 0s - loss: 1.0570 - accuracy: 0.6994 - 24ms/epoch - 4ms/step
# Epoch 163/200
# 6/6 - 0s - loss: 1.0489 - accuracy: 0.6936 - 24ms/epoch - 4ms/step
# Epoch 164/200
# 6/6 - 0s - loss: 1.0393 - accuracy: 0.6994 - 26ms/epoch - 4ms/step
# Epoch 165/200
# 6/6 - 0s - loss: 1.0305 - accuracy: 0.7052 - 26ms/epoch - 4ms/step
# Epoch 166/200
# 6/6 - 0s - loss: 1.0226 - accuracy: 0.6994 - 33ms/epoch - 6ms/step
# Epoch 167/200
# 6/6 - 0s - loss: 1.0141 - accuracy: 0.6994 - 31ms/epoch - 5ms/step
# Epoch 168/200
# 6/6 - 0s - loss: 1.0062 - accuracy: 0.7110 - 28ms/epoch - 5ms/step
# Epoch 169/200
# 6/6 - 0s - loss: 0.9980 - accuracy: 0.7110 - 29ms/epoch - 5ms/step
# Epoch 170/200
# 6/6 - 0s - loss: 0.9908 - accuracy: 0.7052 - 26ms/epoch - 4ms/step
# Epoch 171/200
# 6/6 - 0s - loss: 0.9830 - accuracy: 0.7110 - 26ms/epoch - 4ms/step
# Epoch 172/200
# 6/6 - 0s - loss: 0.9758 - accuracy: 0.7052 - 23ms/epoch - 4ms/step
# Epoch 173/200
# 6/6 - 0s - loss: 0.9683 - accuracy: 0.7052 - 27ms/epoch - 4ms/step
# Epoch 174/200
# 6/6 - 0s - loss: 0.9605 - accuracy: 0.6994 - 25ms/epoch - 4ms/step
# Epoch 175/200
# 6/6 - 0s - loss: 0.9544 - accuracy: 0.6994 - 23ms/epoch - 4ms/step
# Epoch 176/200
# 6/6 - 0s - loss: 0.9477 - accuracy: 0.7110 - 21ms/epoch - 4ms/step
# Epoch 177/200
# 6/6 - 0s - loss: 0.9406 - accuracy: 0.7052 - 25ms/epoch - 4ms/step
# Epoch 178/200
# 6/6 - 0s - loss: 0.9347 - accuracy: 0.7110 - 70ms/epoch - 12ms/step
# Epoch 179/200
# 6/6 - 0s - loss: 0.9278 - accuracy: 0.7052 - 51ms/epoch - 8ms/step
# Epoch 180/200
# 6/6 - 0s - loss: 0.9229 - accuracy: 0.7168 - 47ms/epoch - 8ms/step
# Epoch 181/200
# 6/6 - 0s - loss: 0.9163 - accuracy: 0.7110 - 21ms/epoch - 4ms/step
# Epoch 182/200
# 6/6 - 0s - loss: 0.9093 - accuracy: 0.7110 - 27ms/epoch - 4ms/step
# Epoch 183/200
# 6/6 - 0s - loss: 0.9035 - accuracy: 0.7110 - 26ms/epoch - 4ms/step
# Epoch 184/200
# 6/6 - 0s - loss: 0.8976 - accuracy: 0.7110 - 27ms/epoch - 4ms/step
# Epoch 185/200
# 6/6 - 0s - loss: 0.8926 - accuracy: 0.7110 - 24ms/epoch - 4ms/step
# Epoch 186/200
# 6/6 - 0s - loss: 0.8867 - accuracy: 0.7110 - 23ms/epoch - 4ms/step
# Epoch 187/200
# 6/6 - 0s - loss: 0.8814 - accuracy: 0.7110 - 35ms/epoch - 6ms/step
# Epoch 188/200
# 6/6 - 0s - loss: 0.8762 - accuracy: 0.7168 - 34ms/epoch - 6ms/step
# Epoch 189/200
# 6/6 - 0s - loss: 0.8709 - accuracy: 0.7168 - 39ms/epoch - 7ms/step
# Epoch 190/200
# 6/6 - 0s - loss: 0.8658 - accuracy: 0.7110 - 34ms/epoch - 6ms/step
# Epoch 191/200
# 6/6 - 0s - loss: 0.8613 - accuracy: 0.7168 - 41ms/epoch - 7ms/step
# Epoch 192/200
# 6/6 - 0s - loss: 0.8569 - accuracy: 0.7110 - 37ms/epoch - 6ms/step
# Epoch 193/200
# 6/6 - 0s - loss: 0.8512 - accuracy: 0.7110 - 40ms/epoch - 7ms/step
# Epoch 194/200
# 6/6 - 0s - loss: 0.8471 - accuracy: 0.7052 - 40ms/epoch - 7ms/step
# Epoch 195/200
# 6/6 - 0s - loss: 0.8422 - accuracy: 0.7168 - 41ms/epoch - 7ms/step
# Epoch 196/200
# 6/6 - 0s - loss: 0.8379 - accuracy: 0.7168 - 29ms/epoch - 5ms/step
# Epoch 197/200
# 6/6 - 0s - loss: 0.8347 - accuracy: 0.7110 - 41ms/epoch - 7ms/step
# Epoch 198/200
# 6/6 - 0s - loss: 0.8301 - accuracy: 0.7110 - 35ms/epoch - 6ms/step
# Epoch 199/200
# 6/6 - 0s - loss: 0.8264 - accuracy: 0.7110 - 32ms/epoch - 5ms/step
# Epoch 200/200
# 6/6 - 0s - loss: 0.8214 - accuracy: 0.7110 - 33ms/epoch - 6ms/step

# %%
def generate_seq(model,tokenizer,seed_text,n_words):
    in_text,result=seed_text,seed_text
    for _ in range (n_words):
        encoded=tokenizer.texts_to_sequences([in_text])[0]
        encoded=np.array(encoded)
        yhat=np.argmax(model.predict(encoded,verbose=0))
        out_word=''
        for word, index in tokenizer.word_index.items():
            if index==yhat:
                out_word=word
                break
        in_text,result=out_word,result+' '+out_word
    return result

# %%
print(generate_seq(model,tokenizer,'natural',4))
# Out:
# natural language processing has its
